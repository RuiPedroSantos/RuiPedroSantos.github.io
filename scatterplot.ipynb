# %%
import requests, pandas as pd
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f22e92c-9eb0-4986-84b7-39361e6fc983" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f22e92c-9eb0-4986-84b7-39361e6fc983">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving csvData.csv to csvData.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['csvData.csv']))
df
# Out:
#      rank      country  happiness2021  happiness2020    pop2021
# 0       1      Finland          7.842          7.809   5548.360
# 1       2      Denmark          7.620          7.646   5813.298
# 2       3  Switzerland          7.571          7.560   8715.494
# 3       4      Iceland          7.554          7.504    343.353
# 4       5  Netherlands          7.464          7.449  17173.099
# ..    ...          ...            ...            ...        ...
# 141   142      Lesotho          3.512          3.653   2159.079
# 142   143     Botswana          3.467          3.479   2397.241
# 143   144       Rwanda          3.415          3.312  13276.513
# 144   145     Zimbabwe          3.145          3.299  15092.171
# 145   146  Afghanistan          2.523          2.567  39835.428
#
# [146 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['rank', 'country', 'happiness2021', 'happiness2020', 'pop2021'], dtype='object')

# %%
df = df.drop(["rank", "happiness2021","pop2021"], axis=1)
df
# Out:
#          country  happiness2020
# 0        Finland          7.809
# 1        Denmark          7.646
# 2    Switzerland          7.560
# 3        Iceland          7.504
# 4    Netherlands          7.449
# ..           ...            ...
# 141      Lesotho          3.653
# 142     Botswana          3.479
# 143       Rwanda          3.312
# 144     Zimbabwe          3.299
# 145  Afghanistan          2.567
#
# [146 rows x 2 columns]

# %%
url ='https://www.expertmarket.co.uk/crm-systems/the-ultimate-guide-to-work-place-productivity'
html = requests.get(url)

# %%
pd.read_html(url)
# Out:
# [    Position  ... Productivity per person, per hour
#  0          1  ...                            $84.77
#  1          2  ...                            $49.95
#  2          3  ...                            $49.67
#  3          4  ...                            $47.01
#  4          5  ...                            $44.83
#  5          6  ...                            $42.51
#  6          7  ...                            $41.97
#  7          8  ...                            $41.89
#  8          9  ...                            $40.78
#  9         10  ...                            $38.64
#  10        11  ...                            $36.94
#  11        12  ...                            $36.93
#  12        13  ...                            $35.43
#  13        14  ...                            $35.22
#  14        15  ...                            $33.72
#  15        16  ...                            $31.02
#  16        17  ...                            $30.72
# ...

# %%
tables=pd.read_html(url)

# %%
tables[0]
# Out:
#     Position  ... Productivity per person, per hour
# 0          1  ...                            $84.77
# 1          2  ...                            $49.95
# 2          3  ...                            $49.67
# 3          4  ...                            $47.01
# 4          5  ...                            $44.83
# 5          6  ...                            $42.51
# 6          7  ...                            $41.97
# 7          8  ...                            $41.89
# 8          9  ...                            $40.78
# 9         10  ...                            $38.64
# 10        11  ...                            $36.94
# 11        12  ...                            $36.93
# 12        13  ...                            $35.43
# 13        14  ...                            $35.22
# 14        15  ...                            $33.72
# 15        16  ...                            $31.02
# 16        17  ...                            $30.72
# ...

# %%
df1=tables[0]

# %%
df1.columns
# Out:
# Index(['Position', 'Country', 'Hours worked in 2020', 'GDP per capita',
#        'Productivity per person, per hour'],
#       dtype='object')

# %%
df1=df1.drop(['Position','Hours worked in 2020','GDP per capita'], axis=1)

# %%
df1
# Out:
#                Country Productivity per person, per hour
# 0           Luxembourg                            $84.77
# 1              Ireland                            $49.95
# 2               Norway                            $49.67
# 3          Switzerland                            $47.01
# 4              Denmark                            $44.83
# 5          Netherlands                            $42.51
# 6              Germany                            $41.97
# 7              Austria                            $41.89
# 8              Iceland                            $40.78
# 9               Sweden                            $38.64
# 10       United States                            $36.94
# 11             Belgium                            $36.93
# 12      United Kingdom                            $35.43
# 13              France                            $35.22
# 14             Finland                            $33.72
# ...

# %%
df =df.rename(columns={'country': 'Country'})

# %%
df2=pd.merge(df,df1)
df2
# Out:
#            Country  happiness2020 Productivity per person, per hour
# 0          Finland          7.809                            $33.72
# 1          Denmark          7.646                            $44.83
# 2      Switzerland          7.560                            $47.01
# 3          Iceland          7.504                            $40.78
# 4      Netherlands          7.449                            $42.51
# 5           Norway          7.488                            $49.67
# 6           Sweden          7.353                            $38.64
# 7       Luxembourg          7.238                            $84.77
# 8      New Zealand          7.300                            $25.19
# 9          Austria          7.294                            $41.89
# 10       Australia          7.223                            $31.02
# 11          Israel          7.129                            $23.53
# 12         Germany          7.076                            $41.97
# ...

# %%
df2['Productivity per person, per hour'] = df2['Productivity per person, per hour'].str.replace('$', '')

# %%
df2
# Out:
#            Country  happiness2020 Productivity per person, per hour
# 0          Finland          7.809                             33.72
# 1          Denmark          7.646                             44.83
# 2      Switzerland          7.560                             47.01
# 3          Iceland          7.504                             40.78
# 4      Netherlands          7.449                             42.51
# 5           Norway          7.488                             49.67
# 6           Sweden          7.353                             38.64
# 7       Luxembourg          7.238                             84.77
# 8      New Zealand          7.300                             25.19
# 9          Austria          7.294                             41.89
# 10       Australia          7.223                             31.02
# 11          Israel          7.129                             23.53
# 12         Germany          7.076                             41.97
# ...

# %%
df2.to_csv('happinessandproductivit.csv')
